# %% [markdown]
# # Data Preprocessing Template

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd 
import numpy as np
import sklearn

# %% [markdown]
# ## Read Data Set

# %%
dataset = pd.read_csv('data.csv')

# %% [markdown]
# ## Separating Independent and Dependent variables

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Downloading the Scikit learn and numpy version

# %%
pip uninstall numpy scikit-learn -y
# Out:
# Found existing installation: scikit-learn 1.2.2
# Uninstalling scikit-learn-1.2.2:
#   Successfully uninstalled scikit-learn-1.2.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages)
# WARNING: Skipping numpy as it is not installed.

# %%
pip install numpy==1.26.4 scikit-learn==1.3.2
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting scikit-learn==1.3.2
#   Downloading scikit_learn-1.3.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy>=1.5.0 in d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages (from scikit-learn==1.3.2) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages (from scikit-learn==1.3.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages (from scikit-learn==1.3.2) (3.5.0)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Downloading scikit_learn-1.3.2-cp310-cp310-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.3 MB 6.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/9.3 MB 5.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 5.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.3 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.3 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.3 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: numpy, scikit-learn
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'd:\\Users\\GautamSutar\\anaconda3\\envs\\ai_env\\Lib\\site-packages\\numpy\\linalg\\_umath_linalg.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn.model_selection'
