# %% [markdown]
# # Data Preprocessing Template

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd 
import numpy as np
import sklearn

# %% [markdown]
# ## Read Data Set

# %%
dataset = pd.read_csv('data.csv')

# %% [markdown]
# ## Separating Independent and Dependent variables

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Downloading the Scikit learn and numpy version

# %%
pip uninstall numpy scikit-learn -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages)
# WARNING: Skipping numpy as it is not installed.
# WARNING: Ignoring invalid distribution -umpy (d:\users\gautamsutar\anaconda3\envs\ai_env\lib\site-packages)
# WARNING: Skipping scikit-learn as it is not installed.

# %%
conda init
# Out:
# no change     D:\Users\GautamSutar\anaconda3\Scripts\conda.exe
# no change     D:\Users\GautamSutar\anaconda3\Scripts\conda-env.exe
# no change     D:\Users\GautamSutar\anaconda3\Scripts\conda-script.py
# no change     D:\Users\GautamSutar\anaconda3\Scripts\conda-env-script.py
# no change     D:\Users\GautamSutar\anaconda3\condabin\conda.bat
# no change     D:\Users\GautamSutar\anaconda3\Library\bin\conda.bat
# no change     D:\Users\GautamSutar\anaconda3\condabin\_conda_activate.bat
# no change     D:\Users\GautamSutar\anaconda3\condabin\rename_tmp.bat
# no change     D:\Users\GautamSutar\anaconda3\condabin\conda_auto_activate.bat
# no change     D:\Users\GautamSutar\anaconda3\condabin\conda_hook.bat
# no change     D:\Users\GautamSutar\anaconda3\Scripts\activate.bat
# no change     D:\Users\GautamSutar\anaconda3\condabin\activate.bat
# no change     D:\Users\GautamSutar\anaconda3\condabin\deactivate.bat
# modified      D:\Users\GautamSutar\anaconda3\Scripts\activate
# modified      D:\Users\GautamSutar\anaconda3\Scripts\deactivate
# modified      D:\Users\GautamSutar\anaconda3\etc\profile.d\conda.sh
# modified      D:\Users\GautamSutar\anaconda3\etc\fish\conf.d\conda.fish
# no change     D:\Users\GautamSutar\anaconda3\shell\condabin\Conda.psm1
# modified      D:\Users\GautamSutar\anaconda3\shell\condabin\conda-hook.ps1
# no change     D:\Users\GautamSutar\anaconda3\Lib\site-packages\xontrib\conda.xsh
# modified      D:\Users\GautamSutar\anaconda3\etc\profile.d\conda.csh
# modified      C:\Users\Gautam Sutar\Documents\WindowsPowerShell\profile.ps1
# modified      HKEY_CURRENT_USER\Software\Microsoft\Command Processor\AutoRun
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
#
# Note: you may need to restart the kernel to use updated packages.
